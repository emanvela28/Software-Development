# %% [markdown]
# <a href="https://colab.research.google.com/github/emanvela28/Software-Development/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls /content/dataset/
# Out:
# annotations  data.yaml	images	labels

# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("yolov8n.pt")  # Using YOLOv8 Nano as the base model

# Train on your dataset
model.train(
    data="/content/dataset/data.yaml",  # Path to dataset config
    epochs=50,  # Number of training iterations
    imgsz=640,  # Image size
    batch=16,  # Adjust based on GPU memory (reduce if needed)
    save=True,
    name="tomato_detector"  # Custom name for saving runs
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 366MB/s]
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !nano /content/dataset/data.yaml
# Out:
# /bin/bash: line 1: nano: command not found

# %%
from ultralytics import YOLO

# Load YOLO model
model = YOLO("yolov8n.pt")

# Train the model
model.train(
    data="/content/dataset/data.yaml",  # Fixed dataset path
    epochs=50,
    imgsz=640,
    batch=16,
    save=True,
    name="tomato_detector"
)
# Out:
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
pwd
# Out:
# '/content'

# %%
# !ls -R /content/runs/
# Out:
# /content/runs/:
# detect
#
# /content/runs/detect:
# tomato_detector
#
# /content/runs/detect/tomato_detector:
# args.yaml  weights
#
# /content/runs/detect/tomato_detector/weights:

# %%
# !find /content/runs/detect/ -name "best.pt"

# %%
# !ls -R /content/runs/detect/
# Out:
# ls: cannot access '/content/runs/detect/': No such file or directory

# %%
# !cp /content/runs/detect/tomato_detector/weights/best.pt /content/drive/MyDrive/tomato_model.pt
# Out:
# cp: cannot stat '/content/runs/detect/tomato_detector/weights/best.pt': No such file or directory

# %%
# !find /content/runs/detect/ -name "best.pt"
# Out:
# find: ‘/content/runs/detect/’: No such file or directory

# %%
# !cp /content/runs/detect/tomato_detector2/weights/best.pt /content/drive/MyDrive/tomato_model.pt
# Out:
# cp: cannot stat '/content/runs/detect/tomato_detector2/weights/best.pt': No such file or directory

# %%
from ultralytics import YOLO

# Load YOLO model
model = YOLO("yolov8n.pt")

# Retrain with fewer epochs
model.train(
    data="/content/dataset/data.yaml",
    epochs=10,  # Reduce for faster training
    imgsz=640,
    batch=16,
    save=True,
    name="tomato_detector"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-6ea11cb159e8> in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # Load YOLO model
#       4 model = YOLO("yolov8n.pt")
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.3/949.3 kB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load YOLO model
model = YOLO("yolov8n.pt")

# Retrain with fewer epochs
model.train(
    data="/content/dataset/data.yaml",
    epochs=50,  # Reduce for faster training
    imgsz=640,
    batch=16,
    save=True,
    name="tomato_detector"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 129MB/s]
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls -R /content/runs/detect/tomato_detector/weights/
# Out:
# /content/runs/detect/tomato_detector/weights/:

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="/content/dataset/data.yaml",
    epochs=50,  # Faster retraining
    imgsz=640,
    batch=16,
    save=True,
    name="tomato_detector"
)
# Out:
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls /content/drive/MyDrive/
# Out:
# '2 Much'
#  Abstract.gdoc
# 'Abstract T.O.gdoc'
# 'CamScanner 02-04-2025 14.37.pdf'
# 'Checkpoint 1.gslides'
#  Checkpoint3-slides.gslides
#  Checkpoint3-specs.gdoc
# 'Christmas List.gdoc'
# 'Colab Notebooks'
# 'CompTIA Practice.gdoc'
# 'Copy of Christmas List.gdoc'
# 'CSE 108 Lecture 1.gdoc'
# 'CSE 120'
# 'CSE120 Diagrams'
# 'CSE 120.gdoc'
# 'CSE 150.gdoc'
# 'CSE150 HW-2.gdoc'
#  CSE150-S25-HW1.gdoc
#  CSE150-S25-HW1.pdf
#  dataset.zip
# 'ENGR 156 Essay.gdoc'
# 'ENGR-156 Essay.gdoc'
# 'ENGR 156 In Class Practice.gdoc'
# 'ENGR 156 Lab01.gdoc'
# 'ENGR 156 Microscope.gdoc'
# 'ENGR Assignment 1.gdoc'
#  IMG_0085.mov
#  IMG_0403.mov
#  IMG_0500.mov
#  IMG_0865.mov
#  IMG_0871.mov
#  IMG_0907.mov
#  IMG_1039.mov
#  IMG_1041.mov
#  IMG_1078.mov
#  IMG_1118.mov
#  IMG_1511.mov
#  IMG_1574.mov
#  IMG_2017.mov
#  IMG_2035.mov
#  IMG_2214.mov
#  IMG_2448.mov
#  IMG_2875.mov
#  IMG_2883.mov
#  IMG_3036.mov
#  IMG_3309.mov
#  IMG_3327.mov
#  IMG_3358.mov
#  IMG_3487.mov
#  IMG_5742.mov
# ...

# %%
# !unzip /content/drive/MyDrive/dataset.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/dataset.zip
#    creating: /content/dataset/
#    creating: /content/dataset/annotations/
#   inflating: /content/dataset/annotations/tomato0.xml
#   inflating: /content/dataset/annotations/tomato1.xml
#   inflating: /content/dataset/annotations/tomato10.xml
#   inflating: /content/dataset/annotations/tomato100.xml
#   inflating: /content/dataset/annotations/tomato101.xml
#   inflating: /content/dataset/annotations/tomato102.xml
#   inflating: /content/dataset/annotations/tomato103.xml
#   inflating: /content/dataset/annotations/tomato104.xml
#   inflating: /content/dataset/annotations/tomato105.xml
#   inflating: /content/dataset/annotations/tomato106.xml
#   inflating: /content/dataset/annotations/tomato107.xml
#   inflating: /content/dataset/annotations/tomato108.xml
#   inflating: /content/dataset/annotations/tomato109.xml
#   inflating: /content/dataset/annotations/tomato11.xml
#   inflating: /content/dataset/annotations/tomato110.xml
# ...

# %%
# !cat /content/dataset/data.yaml
# Out:
# path: C:/Users/adamv/OneDrive/OpenCv/tomato_project/dataset
# train: images/train
# val: images/valid
#
# nc: 1  # Number of classes (1 = Tomato)
# names: ["tomato"]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="/content/dataset/data.yaml",
    epochs=50,  # Faster retraining
    imgsz=640,
    batch=16,
    save=True,
    name="tomato_detector"
)
# Out:
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !export LC_ALL=C.UTF-8
# !export LANG=C.UTF-8
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-25-be932058693d> in <cell line: 0>()
# ----> 1 get_ipython().system('export LC_ALL=C.UTF-8')
#       2 get_ipython().system('export LANG=C.UTF-8')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     121       kwargs.update({'also_return_output': True})
#     122
# --> 123     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     124
#     125     if pip_warn:
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
# ...

# %%
# !locale
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-26-3156e0244c83> in <cell line: 0>()
# ----> 1 get_ipython().system('locale')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     121       kwargs.update({'also_return_output': True})
#     122
# --> 123     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     124
#     125     if pip_warn:
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
from google.colab import files
files.download("/content/runs/detect/tomato_detector4/weights/best.pt")

# %%
# !zip -r /content/tomato_project.zip /content/
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-28-929f191d2fee> in <cell line: 0>()
# ----> 1 get_ipython().system('zip -r /content/tomato_project.zip /content/')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     121       kwargs.update({'also_return_output': True})
#     122
# --> 123     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     124
#     125     if pip_warn:
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
# !cp /content/tomato_project.zip /content/drive/MyDrive/
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-29-8916ea033b16> in <cell line: 0>()
# ----> 1 get_ipython().system('cp /content/tomato_project.zip /content/drive/MyDrive/')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     121       kwargs.update({'also_return_output': True})
#     122
# --> 123     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     124
#     125     if pip_warn:
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
# !pip install --upgrade pip
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-30-0ea49165e81b> in <cell line: 0>()
# ----> 1 get_ipython().system('pip install --upgrade pip')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     121       kwargs.update({'also_return_output': True})
#     122
# --> 123     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     124
#     125     if pip_warn:
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...
